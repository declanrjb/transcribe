# %%
from pydub import AudioSegment

# %%
with open('test.txt', 'r') as in_file:
    raw = in_file.read()

# %%
AudioSegment.from_raw(raw)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 AudioSegment.from_raw(raw)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/pydub/audio_segment.py:812, in AudioSegment.from_raw(cls, file, **kwargs)
#     810 @classmethod
#     811 def from_raw(cls, file, **kwargs):
# --> 812     return cls.from_file(file, 'raw', sample_width=kwargs['sample_width'], frame_rate=kwargs['frame_rate'],
#     813                          channels=kwargs['channels'])
#
# KeyError: 'sample_width'
